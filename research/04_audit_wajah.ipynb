# %% [markdown]
# # 04 — Audit dataset wajah
#
# Audit dimulai dari provenance, integritas, duplikasi, dan shortcut teknis. Tidak ada CNN atau model morfologi wajah. Baseline regresi logistik hanya memakai properti teknis file untuk mendeteksi bias koleksi; hasilnya bukan sinyal ASD.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd()
if ROOT.name == 'research':
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'research'))
from run_face_audit import main
main()
# Out:
# {'total_files': 2940, 'readable_images': 2940, 'corrupted': [], 'labels': {'Autistic': 1470, 'Non_Autistic': 1470}, 'formats': {'JPEG': 2940}, 'modes': {'RGB': 2940}, 'top_resolutions': [{'label': 'Non_Autistic', 'width': 179, 'height': 224, 'count': 20}, {'label': 'Non_Autistic', 'width': 182, 'height': 224, 'count': 20}, {'label': 'Non_Autistic', 'width': 173, 'height': 224, 'count': 18}, {'label': 'Non_Autistic', 'width': 181, 'height': 224, 'count': 18}, {'label': 'Non_Autistic', 'width': 180, 'height': 224, 'count': 17}, {'label': 'Non_Autistic', 'width': 178, 'height': 224, 'count': 17}, {'label': 'Non_Autistic', 'width': 184, 'height': 224, 'count': 16}, {'label': 'Non_Autistic', 'width': 171, 'height': 224, 'count': 15}, {'label': 'Non_Autistic', 'width': 175, 'height': 224, 'count': 15}, {'label': 'Non_Autistic', 'width': 177, 'height': 224, 'count': 15}, {'label': 'Non_Autistic', 'width': 169, 'height': 224, 'count': 14}, {'label': 'Non_Autistic', 'width': 183, 'height': 22
# ...

# %%
import json
audit = json.loads((ROOT / 'research' / 'hasil' / 'audit_wajah.json').read_text(encoding='utf-8'))
{'provenance': audit['provenance']['status'], 'shortcut_auc': audit['technical_shortcut_baseline']['auc'], 'decision': audit['decision']}
# Out:
# {'provenance': 'unverified',
#  'shortcut_auc': 0.7515428756536628,
#  'decision': {'status': 'reject_for_asd_modeling_and_quarantine',
#   'included_in_neurogaze_score': False,
#   'cnn_trained': False,
#   'allowed_use': 'None until provenance, license, and consent are documented; detector robustness may be reconsidered afterward.',
#   'reconsider_when': ['Provenance, license, consent, demographics, and label definition are documented.',
#    'Stable participant IDs support identity-grouped evaluation.',
#    'A clinical/ethical review justifies a behaviorally relevant research question.']}}
